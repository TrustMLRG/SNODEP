# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the .npy file
# loss_history = np.load('./results/2d/gene_expression/ndp/gene_exp1/loss_history.npy')
# test_logp_history = np.load('./results/2d/gene_expression/ndp/gene_exp1/test_logp_history.npy')
# test_mse_history = np.load('./results/2d/gene_expression/ndp/gene_exp1/test_mse_history.npy')
# training_time = np.load('./results/2d/gene_expression/ndp/gene_exp1/training_time.npy')
# parameter_count = np.load('./results/2d/gene_expression/ndp/gene_exp1/parameter_count.npy')

# 2 is when all sampling was normal but the context was context:[1:t] target:[t:T], epochs is 100

loss_history_2 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_2/loss_history.npy')
test_logp_history_2 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_2/test_logp_history.npy')
test_mse_history_2 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_2/test_mse_history.npy')
training_time_2 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_2/training_time.npy')
parameter_count_2 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_2/parameter_count.npy')

# 3 is when sampling was poisson the context was context:[1:t] target:[t:T], epochs is 100

loss_history_3 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_3/loss_history.npy')
test_logp_history_3 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_3/test_logp_history.npy')
test_mse_history_3 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_3/test_mse_history.npy')
training_time_3 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_3/training_time.npy')
parameter_count_3 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_3/parameter_count.npy')

# 4 is when sampling was poisson the context was context:[1:t] target:[t:T], but epochs is 300 
loss_history_4 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_4/loss_history.npy')
test_logp_history_4 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_4/test_logp_history.npy')
test_mse_history_4 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_4/test_mse_history.npy')
training_time_4 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_4/training_time.npy')
parameter_count_4 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_4/parameter_count.npy')


# 5 is when sampling was poisson in the pred_y, and log-normal for latent-t0 and d, the context was context:[1:t] target:[t:T], but epochs is 300 
loss_history_5 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_5/loss_history.npy')
test_logp_history_5 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_5/test_logp_history.npy')
test_mse_history_5 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_5/test_mse_history.npy')
training_time_5 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_5/training_time.npy')
parameter_count_5 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_5/parameter_count.npy')

# 6 is when sampling was normal in the pred_y, and normal for latent-t0 and d, the context was context:[1:t] target:[t:T], but epochs is 300 
loss_history_6 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_6/loss_history.npy')
test_logp_history_6 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_6/test_logp_history.npy')
test_mse_history_6 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_6/test_mse_history.npy')
training_time_6 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_6/training_time.npy')
parameter_count_6 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_6/parameter_count.npy')

# 7 is when sampling was normal the context was context:[1:t] target:[t:T], epochs is 300, nll/kl included
loss_history_7 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_7/loss_history.npy')
test_logp_history_7 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_7/test_logp_history.npy')
test_mse_history_7 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_7/test_mse_history.npy')
test_neg_ll_7 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_7/test_neg_ll.npy')
test_kl_7 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_7/test_kl.npy')
training_time_7 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_7/training_time.npy')
parameter_count_7 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_7/parameter_count.npy')

# 8 is when sampling was poisson in the pred_y, and poisson for latent-t0 and d, the context was context:[1:t] target:[t:T], but epochs is 300, nll/kl included 
loss_history_8 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_8/loss_history.npy')
test_logp_history_8 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_8/test_logp_history.npy')
test_mse_history_8 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_8/test_mse_history.npy')
test_neg_ll_8 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_8/test_neg_ll.npy')
test_kl_8 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_8/test_kl.npy')
training_time_8 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_8/training_time.npy')
parameter_count_8 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_8/parameter_count.npy')

# 9 is when sampling was poisson in the pred_y, and poisson for latent-t0 and d, the context was context:[1:t] target:[t:T], but epochs is 300, nll/kl included 
# and lognormal during eval [!!!!!!!!!!!! it was normal earlier and it gives a mse drop !!!!!!!!!!!!!!!!!!]
loss_history_9 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_9/loss_history.npy')
test_logp_history_9 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_9/test_logp_history.npy')
test_mse_history_9 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_9/test_mse_history.npy')
test_neg_ll_9 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_9/test_neg_ll.npy')
test_kl_9 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_9/test_kl.npy')
training_time_9 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_9/training_time.npy')
parameter_count_9 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_9/parameter_count.npy')


# 10 is when sampling was poisson in the pred_y, and poisson for latent-t0 and d, the context was context:[1:t] target:[t:T], but epochs is 300, nll/kl included, total samples is 500, test 100 
loss_history_10 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_10/loss_history.npy')
test_logp_history_10 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_10/test_logp_history.npy')
test_mse_history_10 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_10/test_mse_history.npy')
test_neg_ll_10 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_10/test_neg_ll.npy')
test_kl_10 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_10/test_kl.npy')
training_time_10 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_10/training_time.npy')
parameter_count_10 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_10/parameter_count.npy')

# 11 is when sampling was poisson in the pred_y, and poisson for latent-t0 and d, the context was context:[1:t] target:[t:T], but epochs is 300, nll/kl included, total samples is 50, test 10 
loss_history_11 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_11/loss_history.npy')
test_logp_history_11 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_11/test_logp_history.npy')
test_mse_history_11 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_11/test_mse_history.npy')
test_neg_ll_11 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_11/test_neg_ll.npy')
test_kl_11 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_11/test_kl.npy')
training_time_11 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_11/training_time.npy')
parameter_count_11 = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_11/parameter_count.npy')

loss_history_debug_normal = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_normal/loss_history.npy')
test_logp_history_debug_normal = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_normal/test_logp_history.npy')
test_mse_history_debug_normal = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_normal/test_mse_history.npy')
test_neg_ll_debug_normal = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_normal/test_neg_ll.npy')
test_kl_debug_normal = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_normal/test_kl.npy')
training_time_debug_normal = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_normal/training_time.npy')
parameter_count_debug_normal = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_normal/parameter_count.npy')

loss_history_debug_poisson = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_poisson/loss_history.npy')
test_logp_history_debug_poisson = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_poisson/test_logp_history.npy')
test_mse_history_debug_poisson = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_poisson/test_mse_history.npy')
test_neg_ll_debug_poisson = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_poisson/test_neg_ll.npy')
test_kl_debug_poisson = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_poisson/test_kl.npy')
training_time_debug_poisson = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_poisson/training_time.npy')
parameter_count_debug_poisson = np.load('./results/2d/gene_expression/ndp/gene_exp_time_fixed_debug_poisson/parameter_count.npy')


"""
test_logp_history.npy
test_mse_history.npy
training_time.npy
parameter_count.npy
"""
# Out:
# '\ntest_logp_history.npy\ntest_mse_history.npy\ntraining_time.npy\nparameter_count.npy\n'

# %%
# Inspect the data
print("Data shape:", loss_history.shape)
print("Data type:", type(loss_history))
print("Data example:", loss_history[:5])

# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix
if loss_history.ndim == 1:
    plt.figure(figsize=(10, 5))
    # plt.plot(loss_history_3, label='loss_history_3')
    # plt.plot(loss_history_debug_normal, label='loss_history_debug_normal')
    # plt.plot(loss_history_debug_poisson, label='loss_history_debug_poisson')
    plt.plot(loss_history_4, label='test_mse_history latent normal out poisson')
    plt.plot(loss_history_5, label='test_mse_history all poisson')
    plt.plot(loss_history_6, label='test_mse_history all normal')
    # plt.plot(loss_history_9, label='loss_history_9')
    # # plt.plot(loss_history_10, label='loss_history_10')
    # plt.plot(loss_history_11, label='loss_history_11')
    plt.title('loss-history')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
# Out:
# Data shape: (300,)
# Data type: <class 'numpy.ndarray'>
# Data example: [4036.86037598 2315.85483398 2266.42250977 2252.27397461 2242.92182617]

# %%
# Inspect the data
print("Data shape:", test_logp_history.shape)
print("Data type:", type(test_logp_history))
print("Data example:", test_logp_history[:5])

# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix
if test_logp_history.ndim == 1:
    plt.figure(figsize=(10, 5))
    # plt.plot(test_logp_history_3, label= 'test_logp_history_3')
    # plt.plot(test_logp_history_debug_normal, label= 'test_logp_history_debug_normal')
    # plt.plot(test_logp_history_debug_poisson, label= 'test_logp_history_debug_poisson')
    
    plt.plot(test_logp_history_4, label= 'test_mse_history latent normal out poisson')
    plt.plot(test_logp_history_5, label= 'test_mse_history all poisson')
    plt.plot(test_logp_history_6, label= 'test_mse_history all normal')
    # plt.plot(test_logp_history_9, label= 'test_logp_history_9')
    # # plt.plot(test_logp_history_10, label= 'test_logp_history_10')
    # plt.plot(test_logp_history_11, label= 'test_logp_history_11')
    # plt.title('test-logp-history')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
# Out:
# Data shape: (300,)
# Data type: <class 'numpy.ndarray'>
# Data example: [2280.16796875 2248.26928711 2215.89892578 2220.20800781 2213.9987793 ]

# %%
# Inspect the data
print("Data shape:", test_mse_history.shape)
print("Data type:", type(test_mse_history))
print("Data example:", test_mse_history[:5])

# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix
if test_mse_history.ndim == 1:
    plt.figure(figsize=(10, 5))
    # plt.plot(test_mse_history_3, label= 'test_mse_history_3')
    # plt.plot(test_mse_history_debug_normal, label= 'test_mse_history_debug_normal')
    # plt.plot(test_mse_history_debug_poisson, label= 'test_mse_history_debug_poisson')
    plt.plot(test_mse_history_4, label= 'test_mse_history latent normal out poisson')
    plt.plot(test_mse_history_5, label= 'test_mse_history all poisson')
    plt.plot(test_mse_history_6, label= 'test_mse_history all normal')
    # plt.plot(test_mse_history_9, label= 'test_mse_history_9')
    # # plt.plot(test_mse_history_10, label= 'test_mse_history_10')
    # plt.plot(test_mse_history_11, label= 'test_mse_history_11')
    plt.title('test-mse-history')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.legend()
    plt.show()
# Out:
# Data shape: (300,)
# Data type: <class 'numpy.ndarray'>
# Data example: [0.17154723 0.16701528 0.16763079 0.16714233 0.1671848 ]

# %%
# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix

# Create a figure with two subplots side by side
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Plot the first test KL divergence history on the first subplot
axs[0].plot(test_kl_7.reshape(-1, 10).sum(axis=1), label='test_kl_7')
axs[0].set_title('Test KL 7')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Plot the second test KL divergence history on the second subplot
axs[1].plot(test_kl_8.reshape(-1, 10).sum(axis=1), label='test_kl_8')
axs[1].set_title('Test KL 8')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()

# Display the plots
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_neg_ll_7.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_7')
plt.plot(test_neg_ll_8.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_8')
plt.plot(test_neg_ll_9.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_9')
plt.title('test-neg-ll')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Inspect the data
print("Data shape:", training_time.shape)
print("Data type:", type(training_time))
print("Data example:", training_time[:5])
# Out:
# Data shape: (1,)
# Data type: <class 'numpy.ndarray'>
# Data example: [201.56662297]

# %%
# Inspect the data
print("Data shape:", parameter_count.shape)
print("Data type:", type(parameter_count))
print("Data example:", parameter_count[:5])
# Out:
# Data shape: (1,)
# Data type: <class 'numpy.ndarray'>
# Data example: [135916]
