# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loss_history_2 = np.load('./results/2d/gene_expression/ndp/normal_1000/loss_history.npy')
test_logp_history_2 = np.load('./results/2d/gene_expression/ndp/normal_1000/test_logp_history.npy')
test_mse_history_2 = np.load('./results/2d/gene_expression/ndp/normal_1000/test_mse_history.npy')
test_neg_ll_2 = np.load('./results/2d/gene_expression/ndp/normal_1000/test_neg_ll.npy')
test_kl_2 = np.load('./results/2d/gene_expression/ndp/normal_1000/test_kl.npy')
training_time_2 = np.load('./results/2d/gene_expression/ndp/normal_1000/training_time.npy')
parameter_count_2 = np.load('./results/2d/gene_expression/ndp/normal_1000/parameter_count.npy')


loss_history_3 = np.load('./results/2d/gene_expression/ndp/poisson_1000/loss_history.npy')
test_logp_history_3 = np.load('./results/2d/gene_expression/ndp/poisson_1000/test_logp_history.npy')
test_mse_history_3 = np.load('./results/2d/gene_expression/ndp/poisson_1000/test_mse_history.npy')
test_neg_ll_3 = np.load('./results/2d/gene_expression/ndp/poisson_1000/test_neg_ll.npy')
test_kl_3 = np.load('./results/2d/gene_expression/ndp/poisson_1000/test_kl.npy')
training_time_3 = np.load('./results/2d/gene_expression/ndp/poisson_1000/training_time.npy')
parameter_count_3 = np.load('./results/2d/gene_expression/ndp/poisson_1000/parameter_count.npy')

loss_history_4 = np.load('./results/2d/gene_expression/ndp/latent_normal_end_poisson_1000/loss_history.npy')
test_logp_history_4 = np.load('./results/2d/gene_expression/ndp/latent_normal_end_poisson_1000/test_logp_history.npy')
test_mse_history_4 = np.load('./results/2d/gene_expression/ndp/latent_normal_end_poisson_1000/test_mse_history.npy')
test_neg_ll_4 = np.load('./results/2d/gene_expression/ndp/latent_normal_end_poisson_1000/test_neg_ll.npy')
test_kl_4 = np.load('./results/2d/gene_expression/ndp/latent_normal_end_poisson_1000/test_kl.npy')
training_time_4 = np.load('./results/2d/gene_expression/ndp/latent_normal_end_poisson_1000/training_time.npy')
parameter_count_4 = np.load('./results/2d/gene_expression/ndp/latent_normal_end_poisson_1000/parameter_count.npy')


# weird one, don't consider here on
loss_history_5 = np.load('./results/2d/gene_expression/ndp/latent_lognormal_test_normal_end_poisson_1000/loss_history.npy')
test_logp_history_5 = np.load('./results/2d/gene_expression/ndp/latent_lognormal_test_normal_end_poisson_1000/test_logp_history.npy')
test_mse_history_5 = np.load('./results/2d/gene_expression/ndp/latent_lognormal_test_normal_end_poisson_1000/test_mse_history.npy')
test_neg_ll_5 = np.load('./results/2d/gene_expression/ndp/latent_lognormal_test_normal_end_poisson_1000/test_neg_ll.npy')
test_kl_5 = np.load('./results/2d/gene_expression/ndp/latent_lognormal_test_normal_end_poisson_1000/test_kl.npy')
training_time_5 = np.load('./results/2d/gene_expression/ndp/latent_lognormal_test_normal_end_poisson_1000/training_time.npy')
parameter_count_5 = np.load('./results/2d/gene_expression/ndp/latent_lognormal_test_normal_end_poisson_1000/parameter_count.npy')


loss_history_6 = np.load('./results/2d/gene_expression/ndp/latent_normal_geometric_1000/loss_history.npy')
test_logp_history_6 = np.load('./results/2d/gene_expression/ndp/latent_normal_geometric_1000/test_logp_history.npy')
test_mse_history_6 = np.load('./results/2d/gene_expression/ndp/latent_normal_geometric_1000/test_mse_history.npy')
test_neg_ll_6 = np.load('./results/2d/gene_expression/ndp/latent_normal_geometric_1000/test_neg_ll.npy')
test_kl_6 = np.load('./results/2d/gene_expression/ndp/latent_normal_geometric_1000/test_kl.npy')
training_time_6 = np.load('./results/2d/gene_expression/ndp/latent_normal_geometric_1000/training_time.npy')
parameter_count_6 = np.load('./results/2d/gene_expression/ndp/latent_normal_geometric_1000/parameter_count.npy')
"""

'normal_gene_expression_unseen_tp_test_1000'
"""

loss_history_7 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_unseen_tp_test_1000/loss_history.npy')
test_logp_history_7 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_7 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_7 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_7 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_unseen_tp_test_1000/test_kl.npy')
training_time_7 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_unseen_tp_test_1000/training_time.npy')
parameter_count_7 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_unseen_tp_test_1000/parameter_count.npy')

loss_history_8 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_unseen_tp_test_1000/loss_history.npy')
test_logp_history_8 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_8 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_8 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_8 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_unseen_tp_test_1000/test_kl.npy')
training_time_8 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_unseen_tp_test_1000/training_time.npy')
parameter_count_8 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_unseen_tp_test_1000/parameter_count.npy')


loss_history_9 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_9 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_9 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_9 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_9 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_9 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_9 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_ordered_unseen_tp_test_1000/parameter_count.npy')

loss_history_10 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_10 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_10 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_10 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_10 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_10 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_10 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_ordered_unseen_tp_test_1000/parameter_count.npy')


loss_history_11 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_random_ordering_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_11 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_random_ordering_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_11 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_random_ordering_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_11 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_random_ordering_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_11 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_random_ordering_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_11 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_random_ordering_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_11 = np.load('./results/2d/gene_expression/ndp/normal_gene_expression_random_ordering_ordered_unseen_tp_test_1000/parameter_count.npy')


loss_history_12 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_random_ordering_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_12 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_random_ordering_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_12 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_random_ordering_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_12 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_random_ordering_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_12 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_random_ordering_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_12 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_random_ordering_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_12 = np.load('./results/2d/gene_expression/ndp/poisson_gene_expression_random_ordering_ordered_unseen_tp_test_1000/parameter_count.npy')


loss_history_13 = np.load('./results/2d/gene_expression/ndp/normal_gene_exp_LSTM_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_13 = np.load('./results/2d/gene_expression/ndp/normal_gene_exp_LSTM_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_13 = np.load('./results/2d/gene_expression/ndp/normal_gene_exp_LSTM_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_13 = np.load('./results/2d/gene_expression/ndp/normal_gene_exp_LSTM_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_13 = np.load('./results/2d/gene_expression/ndp/normal_gene_exp_LSTM_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_13 = np.load('./results/2d/gene_expression/ndp/normal_gene_exp_LSTM_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_13 = np.load('./results/2d/gene_expression/ndp/normal_gene_exp_LSTM_ordered_unseen_tp_test_1000/parameter_count.npy')


loss_history_14 = np.load('./results/2d/gene_expression/ndp/poisson_gene_exp_LSTM_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_14 = np.load('./results/2d/gene_expression/ndp/poisson_gene_exp_LSTM_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_14 = np.load('./results/2d/gene_expression/ndp/poisson_gene_exp_LSTM_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_14 = np.load('./results/2d/gene_expression/ndp/poisson_gene_exp_LSTM_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_14 = np.load('./results/2d/gene_expression/ndp/poisson_gene_exp_LSTM_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_14 = np.load('./results/2d/gene_expression/ndp/poisson_gene_exp_LSTM_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_14 = np.load('./results/2d/gene_expression/ndp/poisson_gene_exp_LSTM_ordered_unseen_tp_test_1000/parameter_count.npy')



loss_history_15 = np.load('./results/2d/gene_expression/ndp/normal_LSTM_last_op_1000/loss_history.npy')
test_logp_history_15 = np.load('./results/2d/gene_expression/ndp/normal_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_15 = np.load('./results/2d/gene_expression/ndp/normal_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_15 = np.load('./results/2d/gene_expression/ndp/normal_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_15 = np.load('./results/2d/gene_expression/ndp/normal_LSTM_last_op_1000/test_kl.npy')
training_time_15 = np.load('./results/2d/gene_expression/ndp/normal_LSTM_last_op_1000/training_time.npy')
parameter_count_15 = np.load('./results/2d/gene_expression/ndp/normal_LSTM_last_op_1000/parameter_count.npy')


loss_history_16 = np.load('./results/2d/gene_expression/ndp/poisson_LSTM_last_op_1000/loss_history.npy')
test_logp_history_16 = np.load('./results/2d/gene_expression/ndp/poisson_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_16 = np.load('./results/2d/gene_expression/ndp/poisson_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_16 = np.load('./results/2d/gene_expression/ndp/poisson_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_16 = np.load('./results/2d/gene_expression/ndp/poisson_LSTM_last_op_1000/test_kl.npy')
training_time_16 = np.load('./results/2d/gene_expression/ndp/poisson_LSTM_last_op_1000/training_time.npy')
parameter_count_16 = np.load('./results/2d/gene_expression/ndp/poisson_LSTM_last_op_1000/parameter_count.npy')


loss_history_17 = np.load('./results/2d/gene_expression/ndp/normal_BILSTM_last_op_1000/loss_history.npy')
test_logp_history_17 = np.load('./results/2d/gene_expression/ndp/normal_BILSTM_last_op_1000/test_logp_history.npy')
test_mse_history_17 = np.load('./results/2d/gene_expression/ndp/normal_BILSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_17 = np.load('./results/2d/gene_expression/ndp/normal_BILSTM_last_op_1000/test_neg_ll.npy')
test_kl_17 = np.load('./results/2d/gene_expression/ndp/normal_BILSTM_last_op_1000/test_kl.npy')
training_time_17 = np.load('./results/2d/gene_expression/ndp/normal_BILSTM_last_op_1000/training_time.npy')
parameter_count_17 = np.load('./results/2d/gene_expression/ndp/normal_BILSTM_last_op_1000/parameter_count.npy')


loss_history_18 = np.load('./results/2d/gene_expression/ndp/poisson_BILSTM_last_op_1000/loss_history.npy')
test_logp_history_18 = np.load('./results/2d/gene_expression/ndp/poisson_BILSTM_last_op_1000/test_logp_history.npy')
test_mse_history_18 = np.load('./results/2d/gene_expression/ndp/poisson_BILSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_18 = np.load('./results/2d/gene_expression/ndp/poisson_BILSTM_last_op_1000/test_neg_ll.npy')
test_kl_18 = np.load('./results/2d/gene_expression/ndp/poisson_BILSTM_last_op_1000/test_kl.npy')
training_time_18 = np.load('./results/2d/gene_expression/ndp/poisson_BILSTM_last_op_1000/training_time.npy')
parameter_count_18 = np.load('./results/2d/gene_expression/ndp/poisson_BILSTM_last_op_1000/parameter_count.npy')


loss_history_19 = np.load('./results/2d/gene_expression/ndp/normal_backward_LSTM_last_op_1000/loss_history.npy')
test_logp_history_19 = np.load('./results/2d/gene_expression/ndp/normal_backward_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_19 = np.load('./results/2d/gene_expression/ndp/normal_backward_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_19 = np.load('./results/2d/gene_expression/ndp/normal_backward_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_19 = np.load('./results/2d/gene_expression/ndp/normal_backward_LSTM_last_op_1000/test_kl.npy')
training_time_19 = np.load('./results/2d/gene_expression/ndp/normal_backward_LSTM_last_op_1000/training_time.npy')
parameter_count_19 = np.load('./results/2d/gene_expression/ndp/normal_backward_LSTM_last_op_1000/parameter_count.npy')


loss_history_20 = np.load('./results/2d/gene_expression/ndp/poisson_backward_LSTM_last_op_1000/loss_history.npy')
test_logp_history_20 = np.load('./results/2d/gene_expression/ndp/poisson_backward_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_20 = np.load('./results/2d/gene_expression/ndp/poisson_backward_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_20 = np.load('./results/2d/gene_expression/ndp/poisson_backward_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_20 = np.load('./results/2d/gene_expression/ndp/poisson_backward_LSTM_last_op_1000/test_kl.npy')
training_time_20 = np.load('./results/2d/gene_expression/ndp/poisson_backward_LSTM_last_op_1000/training_time.npy')
parameter_count_20 = np.load('./results/2d/gene_expression/ndp/poisson_backward_LSTM_last_op_1000/parameter_count.npy')


loss_history_21 = np.load('./results/2d/gene_expression/ndp/normal_CDE_backward_LSTM_last_op_1000/loss_history.npy')
test_logp_history_21 = np.load('./results/2d/gene_expression/ndp/normal_CDE_backward_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_21 = np.load('./results/2d/gene_expression/ndp/normal_CDE_backward_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_21 = np.load('./results/2d/gene_expression/ndp/normal_CDE_backward_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_21 = np.load('./results/2d/gene_expression/ndp/normal_CDE_backward_LSTM_last_op_1000/test_kl.npy')
training_time_21 = np.load('./results/2d/gene_expression/ndp/normal_CDE_backward_LSTM_last_op_1000/training_time.npy')
parameter_count_21 = np.load('./results/2d/gene_expression/ndp/normal_CDE_backward_LSTM_last_op_1000/parameter_count.npy')


loss_history_22 = np.load('./results/2d/gene_expression/ndp/poisson_CDE_backward_LSTM_last_op_1000/loss_history.npy')
test_logp_history_22 = np.load('./results/2d/gene_expression/ndp/poisson_CDE_backward_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_22 = np.load('./results/2d/gene_expression/ndp/poisson_CDE_backward_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_22 = np.load('./results/2d/gene_expression/ndp/poisson_CDE_backward_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_22 = np.load('./results/2d/gene_expression/ndp/poisson_CDE_backward_LSTM_last_op_1000/test_kl.npy')
training_time_22 = np.load('./results/2d/gene_expression/ndp/poisson_CDE_backward_LSTM_last_op_1000/training_time.npy')
parameter_count_22 = np.load('./results/2d/gene_expression/ndp/poisson_CDE_backward_LSTM_last_op_1000/parameter_count.npy')


loss_history_23 = np.load('./results/2d/gene_expression/ndp/normal_mean_x_CDE_backward_LSTM_last_op_1000/loss_history.npy')
test_logp_history_23 = np.load('./results/2d/gene_expression/ndp/normal_mean_x_CDE_backward_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_23 = np.load('./results/2d/gene_expression/ndp/normal_mean_x_CDE_backward_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_23 = np.load('./results/2d/gene_expression/ndp/normal_mean_x_CDE_backward_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_23 = np.load('./results/2d/gene_expression/ndp/normal_mean_x_CDE_backward_LSTM_last_op_1000/test_kl.npy')
training_time_23 = np.load('./results/2d/gene_expression/ndp/normal_mean_x_CDE_backward_LSTM_last_op_1000/training_time.npy')
parameter_count_23 = np.load('./results/2d/gene_expression/ndp/normal_mean_x_CDE_backward_LSTM_last_op_1000/parameter_count.npy')


loss_history_24 = np.load('./results/2d/gene_expression/ndp/poisson_mean_x_CDE_backward_LSTM_last_op_1000/loss_history.npy')
test_logp_history_24 = np.load('./results/2d/gene_expression/ndp/poisson_mean_x_CDE_backward_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_24 = np.load('./results/2d/gene_expression/ndp/poisson_mean_x_CDE_backward_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_24 = np.load('./results/2d/gene_expression/ndp/poisson_mean_x_CDE_backward_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_24 = np.load('./results/2d/gene_expression/ndp/poisson_mean_x_CDE_backward_LSTM_last_op_1000/test_kl.npy')
training_time_24 = np.load('./results/2d/gene_expression/ndp/poisson_mean_x_CDE_backward_LSTM_last_op_1000/training_time.npy')
parameter_count_24 = np.load('./results/2d/gene_expression/ndp/poisson_mean_x_CDE_backward_LSTM_last_op_1000/parameter_count.npy')



##### adhoc for odernn

loss_history_25 = np.load('./results/2d/m171/flux/ndp/m171_flux_nodep/loss_history.npy')
test_logp_history_25 = np.load('./results/2d/m171/flux/ndp/m171_flux_nodep/test_logp_history.npy')
test_mse_history_25 = np.load('./results/2d/m171/flux/ndp/m171_flux_nodep/test_mse_history.npy')
test_neg_ll_25 = np.load('./results/2d/m171/flux/ndp/m171_flux_nodep/test_neg_ll.npy')
test_kl_25 = np.load('./results/2d/m171/flux/ndp/m171_flux_nodep/test_kl.npy')
training_time_25 = np.load('./results/2d/m171/flux/ndp/m171_flux_nodep/training_time.npy')
parameter_count_25 = np.load('./results/2d/m171/flux/ndp/m171_flux_nodep/parameter_count.npy')

loss_history_26 = np.load('./results/2d/m171/flux/ndp/m171_flux_snodep/loss_history.npy')
test_logp_history_26 = np.load('./results/2d/m171/flux/ndp/m171_flux_snodep/test_logp_history.npy')
test_mse_history_26 = np.load('./results/2d/m171/flux/ndp/m171_flux_snodep/test_mse_history.npy')
test_neg_ll_26 = np.load('./results/2d/m171/flux/ndp/m171_flux_snodep/test_neg_ll.npy')
test_kl_26 = np.load('./results/2d/m171/flux/ndp/m171_flux_snodep/test_kl.npy')
training_time_26 = np.load('./results/2d/m171/flux/ndp/m171_flux_snodep/training_time.npy')
parameter_count_26 = np.load('./results/2d/m171/flux/ndp/m171_flux_snodep/parameter_count.npy')

loss_history_27 = np.load('./results/2d/m171/flux/single_gene/ndp/m171_flux_snodep_sanity_check_ode_encoder/loss_history.npy')
test_logp_history_27 = np.load('./results/2d/m171/flux/single_gene/ndp/m171_flux_snodep_sanity_check_ode_encoder/test_logp_history.npy')
test_mse_history_27 = np.load('./results/2d/m171/flux/single_gene/ndp/m171_flux_snodep_sanity_check_ode_encoder/test_mse_history.npy')
test_neg_ll_27 = np.load('./results/2d/m171/flux/single_gene/ndp/m171_flux_snodep_sanity_check_ode_encoder/test_neg_ll.npy')
test_kl_27 = np.load('./results/2d/m171/flux/single_gene/ndp/m171_flux_snodep_sanity_check_ode_encoder/test_kl.npy')
training_time_27 = np.load('./results/2d/m171/flux/single_gene/ndp/m171_flux_snodep_sanity_check_ode_encoder/training_time.npy')
parameter_count_27 = np.load('./results/2d/m171/flux/single_gene/ndp/m171_flux_snodep_sanity_check_ode_encoder/parameter_count.npy')


loss_history_28 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_nodep/loss_history.npy')
test_logp_history_28 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_nodep/test_logp_history.npy')
test_mse_history_28 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_nodep/test_mse_history.npy')
test_neg_ll_28 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_nodep/test_neg_ll.npy')
test_kl_28 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_nodep/test_kl.npy')
training_time_28 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_nodep/training_time.npy')
parameter_count_28 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_nodep/parameter_count.npy')

loss_history_29 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep/loss_history.npy')
test_logp_history_29 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep/test_logp_history.npy')
test_mse_history_29 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep/test_mse_history.npy')
test_neg_ll_29 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep/test_neg_ll.npy')
test_kl_29 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep/test_kl.npy')
training_time_29 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep/training_time.npy')
parameter_count_29 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep/parameter_count.npy')

loss_history_30 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder/loss_history.npy')
test_logp_history_30 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder/test_logp_history.npy')
test_mse_history_30 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder/test_mse_history.npy')
test_neg_ll_30 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder/test_neg_ll.npy')
test_kl_30 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder/test_kl.npy')
training_time_30 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder/training_time.npy')
parameter_count_30 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder/parameter_count.npy')


loss_history_31 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial/loss_history.npy')
test_logp_history_31 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial/test_logp_history.npy')
test_mse_history_31 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial/test_mse_history.npy')
test_neg_ll_31 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial/test_neg_ll.npy')
test_kl_31 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial/test_kl.npy')
training_time_31 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial/training_time.npy')
parameter_count_31 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial/parameter_count.npy')



loss_history_32 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial/loss_history.npy')
test_logp_history_32 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial/test_logp_history.npy')
test_mse_history_32 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial/test_mse_history.npy')
test_neg_ll_32 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial/test_neg_ll.npy')
test_kl_32 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial/test_kl.npy')
training_time_32 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial/training_time.npy')
parameter_count_32 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial/parameter_count.npy')


loss_history_33 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4/loss_history.npy')
test_logp_history_33 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4/test_logp_history.npy')
test_mse_history_33 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4/test_mse_history.npy')
test_neg_ll_33 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4/test_neg_ll.npy')
test_kl_33 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4/test_kl.npy')
training_time_33 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4/training_time.npy')
parameter_count_33 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4/parameter_count.npy')

# m171_geneexpr_snodep_sanity_check_poisson_ode_encoder

# these both are with 1e-5 lr
loss_history_34 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_ode_encoder/loss_history.npy')
test_logp_history_34 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_ode_encoder/test_logp_history.npy')
test_mse_history_34 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_ode_encoder/test_mse_history.npy')
test_neg_ll_34 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_ode_encoder/test_neg_ll.npy')
test_kl_34 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_ode_encoder/test_kl.npy')
training_time_34 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_ode_encoder/training_time.npy')
parameter_count_34 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_ode_encoder/parameter_count.npy')



loss_history_35 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder/loss_history.npy')
test_logp_history_35 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder/test_logp_history.npy')
test_mse_history_35 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder/test_mse_history.npy')
test_neg_ll_35 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder/test_neg_ll.npy')
test_kl_35 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder/test_kl.npy')
training_time_35 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder/training_time.npy')
parameter_count_35 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder/parameter_count.npy')


loss_history_36 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005/loss_history.npy')
test_logp_history_36 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005/test_logp_history.npy')
test_mse_history_36 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005/test_mse_history.npy')
test_neg_ll_36 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005/test_neg_ll.npy')
test_kl_36 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005/test_kl.npy')
training_time_36 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005/training_time.npy')
parameter_count_36 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005/parameter_count.npy')

# ^ this performs better than snodep, performing again: it performs as good as snodep, but is much slower

loss_history_37 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005/loss_history.npy')
test_logp_history_37 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005/test_logp_history.npy')
test_mse_history_37 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005/test_mse_history.npy')
test_neg_ll_37 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005/test_neg_ll.npy')
test_kl_37 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005/test_kl.npy')
training_time_37 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005/training_time.npy')
parameter_count_37 = np.load('./results/2d/m171/gene_expression/single_gene/ndp/m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005/parameter_count.npy')

"""
1. poisson_but_latent_normal: means that everything is poisson but during test, the sampling is coming from normal
2. unseen_tp is not really unseen_tp, there was a bug here, need to do it again
I've declared a new variable called ordered_time for it
3. random_ordering_ordered_unseen means that context_target_split is not seeing the test timepoints but what goes into encoder is random times
4. ordered_unseen means context_target_split is not seeing the test timepoints but what goes into encoder is ascending ordered times
"""
# Out:
# "\n1. poisson_but_latent_normal: means that everything is poisson but during test, the sampling is coming from normal\n2. unseen_tp is not really unseen_tp, there was a bug here, need to do it again\nI've declared a new variable called ordered_time for it\n3. random_ordering_ordered_unseen means that context_target_split is not seeing the test timepoints but what goes into encoder is random times\n4. ordered_unseen means context_target_split is not seeing the test timepoints but what goes into encoder is ascending ordered times\n"

# %%
plt.figure(figsize=(10, 5))
# plt.plot(loss_history_2, label='loss_history_normal')
# plt.plot(loss_history_3, label='loss_history_poisson')
# plt.plot(loss_history_4, label='loss_history_latent_normal_end_poisson')
# # plt.plot(loss_history_5, label='loss_history_poisson_but_latent_normal')
# plt.plot(loss_history_6, label='loss_history_latent_normal_geometric')
# plt.plot(loss_history_7, label='loss_history_normal_unseen')
# plt.plot(loss_history_8, label='loss_history_poisson_unseen')

# plt.plot(loss_history_9, label='loss_history_normal_ordered_unseen')
# plt.plot(loss_history_10, label='loss_history_poisson_ordered_unseen')

# plt.plot(loss_history_11, label='loss_history_normal_random_ordering_ordered_unseen')
# plt.plot(loss_history_12, label='loss_history_poisson_random_ordering_ordered_unseen')

# plt.plot(loss_history_13, label='loss_history_normal_LSTM_ordered_unseen')
# plt.plot(loss_history_14, label='loss_history_poisson_LSTM_ordered_unseen')

# plt.plot(loss_history_15, label='loss_history_normal_LSTM_last_op')
# plt.plot(loss_history_16, label='loss_history_poisson_LSTM_last_op')

# plt.plot(loss_history_17, label='loss_history_normal_BILSTM_last_op')
# plt.plot(loss_history_18, label='loss_history_poisson_BILSTM_last_op')

# plt.plot(loss_history_19, label='loss_history_normal_backward_LSTM_last_op')
# plt.plot(loss_history_20, label='loss_history_poisson_backward_LSTM_last_op')

# plt.plot(loss_history_21, label='loss_history_normal_CDE_backward_LSTM_last_op')
# plt.plot(loss_history_22, label='loss_history_poisson_CDE_backward_LSTM_last_op')

# plt.plot(loss_history_23, label='loss_history_mean_x_normal_CDE_backward_LSTM_last_op')
# plt.plot(loss_history_24, label='loss_history_mean_x_poisson_CDE_backward_LSTM_last_op')

# plt.plot(loss_history_25, label='loss_history_m171_flux_nodep')
# plt.plot(loss_history_26, label='loss_history_m171_flux_snodep')
# plt.plot(loss_history_27, label='loss_history_m171_flux_snodep_sanity_check_ode_encoder')

# plt.plot(loss_history_28, label='loss_history_m171_geneexpr_nodep')
plt.plot(loss_history_29, label='loss_history_m171_geneexpr_snodep')
plt.plot(loss_history_30, label='loss_history_m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder')
plt.plot(loss_history_31, label='loss_history_m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial')
plt.plot(loss_history_32, label='loss_history_m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial')
plt.plot(loss_history_33, label='loss_history_m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4')
plt.plot(loss_history_34, label='loss_history_m171_geneexpr_snodep_sanity_check_poisson_ode_encoder')
plt.plot(loss_history_35, label='loss_history_m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder')
plt.plot(loss_history_36, label='loss_history_m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005')
plt.plot(loss_history_37, label='loss_history_m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005')
plt.title('loss-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(test_logp_history_2, label= 'test_logp_history_normal')
# plt.plot(test_logp_history_3, label= 'test_logp_history_poisson')
# plt.plot(test_logp_history_4, label= 'test_logp_history_latent_normal_end_poisson')
# # plt.plot(test_logp_history_5, label= 'test_logp_history_poisson_but_latent_normal')
# plt.plot(test_logp_history_6, label= 'test_logp_history_latent_normal_geometric')
# plt.plot(test_logp_history_7, label= 'test_logp_history_normal_unseen')
# plt.plot(test_logp_history_8, label= 'test_logp_history_poisson_unseen')

# plt.plot(test_logp_history_9, label= 'test_logp_history_normal_ordered_unseen')
# plt.plot(test_logp_history_10, label= 'test_logp_history_poisson_ordered_unseen')

# plt.plot(test_logp_history_11, label= 'test_logp_history_normal_random_ordering_ordered_unseen')
# plt.plot(test_logp_history_12, label= 'test_logp_history_poisson_random_ordering_ordered_unseen')

# plt.plot(test_logp_history_13, label= 'test_logp_history_normal_LSTM_ordered_unseen')
# plt.plot(test_logp_history_14, label= 'test_logp_history_poisson_LSTM_ordered_unseen')

# plt.plot(test_logp_history_15, label= 'test_logp_history_normal_LSTM_last_op')
# plt.plot(test_logp_history_16, label= 'test_logp_history_poisson_LSTM_last_op')

# plt.plot(test_logp_history_17, label= 'test_logp_history_normal_BILSTM_last_op')
# plt.plot(test_logp_history_18, label= 'test_logp_history_poisson_BILSTM_last_op')


# plt.plot(test_logp_history_19, label= 'test_logp_history_normal_backward_LSTM_last_op')
# plt.plot(test_logp_history_20, label= 'test_logp_history_poisson_backward_LSTM_last_op')

# plt.plot(test_logp_history_21, label= 'test_logp_history_normal_CDE_backward_LSTM_last_op')
# plt.plot(test_logp_history_22, label= 'test_logp_history_poisson_CDE_backward_LSTM_last_op')

# plt.plot(test_logp_history_23, label= 'test_logp_history_mean_x_normal_CDE_backward_LSTM_last_op')
# plt.plot(test_logp_history_24, label= 'test_logp_history_mean_x_poisson_CDE_backward_LSTM_last_op')

# plt.plot(test_logp_history_25, label= 'test_logp_history_m171_flux_nodep')
# plt.plot(test_logp_history_26, label= 'test_logp_history_m171_flux_snodep')
# plt.plot(test_logp_history_27, label= 'test_logp_history_m171_flux_snodep_sanity_check_ode_encoder')

plt.plot(test_logp_history_28, label= 'test_logp_history_m171_geneexpr_nodep')
plt.plot(test_logp_history_29, label= 'test_logp_history_m171_geneexpr_snodep')
plt.plot(test_logp_history_30, label= 'test_logp_history_m171_geneexpr_snodep_sanity_check_ode_encoder')
plt.plot(test_logp_history_31, label= 'test_logp_history_m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial')
plt.plot(test_logp_history_32, label= 'test_logp_history_m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial')
plt.plot(test_logp_history_33, label= 'test_logp_history_m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4')
plt.plot(test_logp_history_34, label= 'test_logp_history_m171_geneexpr_snodep_sanity_check_poisson_ode_encoder')
plt.plot(test_logp_history_35, label= 'test_logp_history_m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder')
plt.plot(test_logp_history_36, label= 'test_logp_history_m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005')
plt.plot(test_logp_history_37, label= 'test_logp_history_m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005')
plt.title('test-logp-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(test_mse_history_2, label= 'test_mse_history_normal')
# plt.plot(test_mse_history_3, label= 'test_mse_history_poisson')
# plt.plot(test_mse_history_4, label= 'test_mse_history_latent_normal_end_poisson')
# # plt.plot(test_mse_history_5, label= 'test_mse_history_poisson_but_latent_normal')
# plt.plot(test_mse_history_6, label= 'test_mse_history_latent_normal_geometric')
# plt.plot(test_mse_history_7, label= 'test_mse_history_normal_unseen')
# plt.plot(test_mse_history_8, label= 'test_mse_history_poisson_unseen')

# plt.plot(test_mse_history_9, label= 'test_mse_history_normal_ordered_unseen')
# plt.plot(test_mse_history_10, label= 'test_mse_history_poisson_ordered_unseen')

# plt.plot(test_mse_history_11, label= 'test_mse_history_normal_random_ordering_ordered_unseen')
# plt.plot(test_mse_history_12, label= 'test_mse_history_poisson_random_ordering_ordered_unseen')

# plt.plot(test_mse_history_13, label= 'test_mse_history_normal_LSTM_ordered_unseen')
# # plt.plot(test_mse_history_14, label= 'test_mse_history_poisson_LSTM_ordered_unseen')

# plt.plot(test_mse_history_15, label= 'test_mse_history_normal_LSTM_last_op')
# plt.plot(test_mse_history_16, label= 'test_mse_history_poisson_LSTM_last_op')

# plt.plot(test_mse_history_17, label= 'test_mse_history_normal_BILSTM_last_op')
# plt.plot(test_mse_history_18, label= 'test_mse_history_poisson_BILSTM_last_op')

# plt.plot(test_mse_history_19, label= 'test_mse_history_normal_backward_LSTM_last_op')
# plt.plot(test_mse_history_20, label= 'test_mse_history_poisson_backward_LSTM_last_op')

# plt.plot(test_mse_history_21, label= 'test_mse_history_normal_CDE_backward_LSTM_last_op')
# plt.plot(test_mse_history_22, label= 'test_mse_history_poisson_CDE_backward_LSTM_last_op')

# plt.plot(test_mse_history_23, label= 'test_mse_history_mean_x_normal_CDE_backward_LSTM_last_op')
# plt.plot(test_mse_history_24, label= 'test_mse_history_mean_x_poisson_CDE_backward_LSTM_last_op')
# plt.plot(test_mse_history_25, label= 'test_mse_history_m171_flux_nodep')
# plt.plot(test_mse_history_26, label= 'test_mse_history_m171_flux_snodep')
# plt.plot(test_mse_history_27, label= 'test_mse_history_m171_flux_snodep_sanity_check_ode_encoder')

plt.plot(test_mse_history_28, label= 'test_mse_history_m171_geneexpr_nodep')
plt.plot(test_mse_history_29, label= 'test_mse_history_m171_geneexpr_snodep')
# plt.plot(test_mse_history_30[300:], label= 'test_mse_history_m171_geneexpr_snodep_sanity_check_nbinomial_ode_encoder')
# plt.plot(test_mse_history_31, label= 'test_mse_history_m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial')
# plt.plot(test_mse_history_32[50:], label= 'test_mse_history_m171_geneexpr_snodep_sanity_check_lstm_last_nbinomial_1e4')
plt.plot(test_mse_history_33[50:], label= 'test_mse_history_m171_geneexpr_snodep_sanity_check_ode_encoder_nbinomial_1e4')
# plt.plot(test_mse_history_34[300:], label= 'test_mse_history_m171_geneexpr_snodep_sanity_check_poisson_ode_encoder')
# plt.plot(test_mse_history_35[300:], label= 'test_mse_history_m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder')
plt.plot(test_mse_history_36, label= 'test_mse_history_m171_geneexpr_snodep_sanity_check_poisson_gruode_encoder_0005')
plt.plot(test_mse_history_37, label= 'test_mse_history_m171_geneexpr_snodep_sanity_check_poisson_lstmode_encoder_0005')

plt.title('test-mse-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(10, 5))
#       2 # plt.plot(test_mse_history_2, label= 'test_mse_history_normal')
#       3 # plt.plot(test_mse_history_3, label= 'test_mse_history_poisson')
#       4 # plt.plot(test_mse_history_4, label= 'test_mse_history_latent_normal_end_poisson')
#    (...)
#      34 # plt.plot(test_mse_history_26, label= 'test_mse_history_m171_flux_snodep')
#      35 # plt.plot(test_mse_history_27, label= 'test_mse_history_m171_flux_snodep_sanity_check_ode_encoder')
#      37 plt.plot(test_mse_history_28, label= 'test_mse_history_m171_geneexpr_nodep')
#
# NameError: name 'plt' is not defined

# %%
# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix

# Create a figure with two subplots side by side
fig, axs = plt.subplots(1, 5, figsize=(15, 5))

# Plot the first test KL divergence history on the first subplot
axs[0].plot(test_kl_2.reshape(-1, 10).sum(axis=1), label='test_kl_normal')
axs[0].set_title('Test KL normal')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Plot the second test KL divergence history on the second subplot
axs[1].plot(test_kl_3.reshape(-1, 10).sum(axis=1), label='test_kl_poisson')
axs[1].set_title('Test KL poisson')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()

# Plot the second test KL divergence history on the second subplot
axs[2].plot(test_kl_4.reshape(-1, 10).sum(axis=1), label='test_kl_latent_normal_end_poisson')
axs[2].set_title('Test KL latent normal end poisson')
axs[2].set_xlabel('iteration')
axs[2].set_ylabel('Loss')
axs[2].legend()

axs[3].plot(test_kl_5.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_but_latent_normal')
axs[3].set_title('Test KL latent normal end poisson')
axs[3].set_xlabel('iteration')
axs[3].set_ylabel('Loss')
axs[3].legend()

axs[4].plot(test_kl_6.reshape(-1, 10).sum(axis=1), label='test_kl_latent_normal_geometric')
axs[4].set_title('Test KL normal')
axs[4].set_xlabel('iteration')
axs[4].set_ylabel('Loss')
axs[4].legend()

# Display the plots
plt.show()



fig, axs = plt.subplots(1, 4, figsize=(15, 5))
# Plot the first test KL divergence history on the first subplot

axs[0].plot(test_kl_7.reshape(-1, 10).sum(axis=1), label='test_kl_normal_unseen')
axs[0].set_title('Test KL normal')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(test_kl_8.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_unseen')
axs[1].set_title('Test KL normal')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()

axs[2].plot(test_kl_9.reshape(-1, 10).sum(axis=1), label='test_kl_normal_ordered_unseen')
axs[2].set_title('Test KL normal')
axs[2].set_xlabel('iteration')
axs[2].set_ylabel('Loss')
axs[2].legend()

axs[3].plot(test_kl_10.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_ordered_unseen')
axs[3].set_title('Test KL normal')
axs[3].set_xlabel('iteration')
axs[3].set_ylabel('Loss')
axs[3].legend()
plt.show()


fig, axs = plt.subplots(1, 4, figsize=(15, 5))

axs[2].plot(test_kl_11.reshape(-1, 10).sum(axis=1), label='test_kl_normal_random_ordering_ordered_unseen')
axs[2].set_title('Test KL normal')
axs[2].set_xlabel('iteration')
axs[2].set_ylabel('Loss')
axs[2].legend()

axs[3].plot(test_kl_12.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_random_ordering_ordered_unseen')
axs[3].set_title('Test KL normal')
axs[3].set_xlabel('iteration')
axs[3].set_ylabel('Loss')
axs[3].legend()

axs[0].plot(test_kl_13.reshape(-1, 10).sum(axis=1), label='test_kl_normal_LSTM_ordered_unseen')
axs[0].set_title('Test KL normal')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(test_kl_14.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_LSTM_ordered_unseen')
axs[1].set_title('Test KL normal')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()
plt.show()

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

axs[0].plot(test_kl_15.reshape(-1, 10).sum(axis=1), label='test_kl_normal_LSTM_last_op')
axs[0].set_title('Test KL normal')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(test_kl_16.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_LSTM_last_op')
axs[1].set_title('Test KL normal')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()


axs[2].plot(test_kl_17.reshape(-1, 10).sum(axis=1), label='test_kl_normal_BILSTM_last_op')
axs[2].set_title('Test KL normal')
axs[2].set_xlabel('iteration')
axs[2].set_ylabel('Loss')
axs[2].legend()

axs[3].plot(test_kl_18.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_BILSTM_last_op')
axs[3].set_title('Test KL normal')
axs[3].set_xlabel('iteration')
axs[3].set_ylabel('Loss')
axs[3].legend()

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

axs[0].plot(test_kl_19.reshape(-1, 10).sum(axis=1), label='test_kl_normal_backward_LSTM_last_op')
axs[0].set_title('Test KL normal')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(test_kl_20.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_backward_LSTM_last_op')
axs[1].set_title('Test KL normal')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()


axs[2].plot(test_kl_21.reshape(-1, 10).sum(axis=1), label='test_kl_normal_CDE_backward_LSTM_last_op')
axs[2].set_title('Test KL normal')
axs[2].set_xlabel('iteration')
axs[2].set_ylabel('Loss')
axs[2].legend()

axs[3].plot(test_kl_22.reshape(-1, 10).sum(axis=1), label='test_kl_poisson_CDE_backward_LSTM_last_op')
axs[3].set_title('Test KL normal')
axs[3].set_xlabel('iteration')
axs[3].set_ylabel('Loss')
axs[3].legend()

# %%
plt.figure(figsize=(10, 5))
# # plt.plot(test_neg_ll_2.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal')
# plt.plot(test_neg_ll_3.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson')
# plt.plot(test_neg_ll_4.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_latent_normal_end_poisson')
# plt.plot(test_neg_ll_5.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_but_latent_normal')
# plt.plot(test_neg_ll_6.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_latent_normal_geometric')
# plt.plot(test_neg_ll_7.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_unseen')
plt.plot(test_neg_ll_8.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_unseen')

# plt.plot(test_neg_ll_9.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_ordered_unseen')
plt.plot(test_neg_ll_10.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_ordered_unseen')


# plt.plot(test_neg_ll_11.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_random_ordering_ordered_unseen')
plt.plot(test_neg_ll_12.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_random_ordering_ordered_unseen')


# plt.plot(test_neg_ll_13.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_LSTM_ordered_unseen')
plt.plot(test_neg_ll_14.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_LSTM_ordered_unseen')

# plt.plot(test_neg_ll_15.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_LSTM_last_op')
plt.plot(test_neg_ll_16.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_LSTM_last_op')

# plt.plot(test_neg_ll_17.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_BILSTM_last_op')
plt.plot(test_neg_ll_18.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_BILSTM_last_op')


# plt.plot(test_neg_ll_19.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_backward_LSTM_last_op')
plt.plot(test_neg_ll_20.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_backward_LSTM_last_op')

# plt.plot(test_neg_ll_21.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_CDE_backward_LSTM_last_op')
plt.plot(test_neg_ll_22.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_poisson_CDE_backward_LSTM_last_op')

plt.title('test-neg-ll')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Inspect the data
print("Data shape:", training_time.shape)
print("Data type:", type(training_time))
print("Data example:", training_time[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Inspect the data
# ----> 2 print("Data shape:", training_time.shape)
#       3 print("Data type:", type(training_time))
#       4 print("Data example:", training_time[:5])
#
# NameError: name 'training_time' is not defined

# %%
# Inspect the data
print("Data shape:", parameter_count.shape)
print("Data type:", type(parameter_count))
print("Data example:", parameter_count[:5])
# Out:
# Data shape: (1,)
# Data type: <class 'numpy.ndarray'>
# Data example: [135916]

# %% [markdown]
# ## Figures for paper

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_mse_history_2, label= 'Neural ODE Process')
plt.plot(test_mse_history_9, label= 'Neural ODE Process with ordered time')
# plt.plot(test_mse_history_24, label= 'test_mse_history_mean_x_poisson_CDE_backward_LSTM_last_op')
plt.plot(test_mse_history_20, label= 'CSNODEP')
plt.title('test-mse-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix

# # Create a figure with two subplots side by side
# fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# # Plot the first test KL divergence history on the first subplot
# axs[0].plot(test_kl_2.reshape(-1, 10).sum(axis=1), label='Neural ODE Process')
# axs[0].set_title('Test KL normal')
# axs[0].set_xlabel('iteration')
# axs[0].set_ylabel('Loss')
# axs[0].legend()

# axs[1].plot(test_kl_9.reshape(-1, 10).sum(axis=1), label='Neural ODE Process with ordered time')
# axs[1].set_title('Test KL normal')
# axs[1].set_xlabel('iteration')
# axs[1].set_ylabel('Loss')
# axs[1].legend()


# axs[2].plot(test_kl_20.reshape(-1, 10).sum(axis=1), label='CSNODEP')
# axs[2].set_title('Test KL normal')
# axs[2].set_xlabel('iteration')
# axs[2].set_ylabel('Loss')
# axs[2].legend()

# plt.show()


plt.figure(figsize=(10, 5))
plt.plot(test_kl_2.reshape(-1, 10).sum(axis=1), label= 'Neural ODE Process')
plt.plot(test_kl_9.reshape(-1, 10).sum(axis=1), label= 'Neural ODE Process with ordered time')
# plt.plot(test_mse_history_24, label= 'test_mse_history_mean_x_poisson_CDE_backward_LSTM_last_op')
plt.plot(test_kl_20.reshape(-1, 10).sum(axis=1), label= 'CSNODEP')
plt.title('KL-Divergence term')
plt.xlabel('epochs')
plt.ylabel('KL-loss')
plt.legend()
plt.show()
