# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loss_history_2 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_lognormal/loss_history.npy')
test_logp_history_2 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_lognormal/test_logp_history.npy')
test_mse_history_2 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_lognormal/test_mse_history.npy')
test_neg_ll_2 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_lognormal/test_neg_ll.npy')
test_kl_2 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_lognormal/test_kl.npy')
training_time_2 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_lognormal/training_time.npy')
parameter_count_2 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_lognormal/parameter_count.npy')

loss_history_3 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_normal/loss_history.npy')
test_logp_history_3 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_normal/test_logp_history.npy')
test_mse_history_3 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_normal/test_mse_history.npy')
test_neg_ll_3 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_normal/test_neg_ll.npy')
test_kl_3 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_normal/test_kl.npy')
training_time_3 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_normal/training_time.npy')
parameter_count_3 = np.load('./results/2d/m171/gene_expression/ndp/m171_geneexpr_snodep_latent_normal/parameter_count.npy')

# %%
plt.figure(figsize=(10, 5))
# gene_expr
plt.plot(loss_history_2, label='lognormal L loss_history-SNODEP')
plt.plot(loss_history_3, label='normal L loss_history-SNODEP')

plt.title('loss-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
# gene_expr
plt.plot(test_logp_history_2, label= 'lognormal L test_logp_history-SNODEP')
plt.plot(test_logp_history_3, label= 'normal L test_logp_history-SNODEP')

plt.title('test-logp-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
# gene_expr
plt.plot(test_mse_history_2, label= 'lognormal L test_mse_history-SNODEP')
plt.plot(test_mse_history_3, label= 'normal L test_mse_history-SNODEP')


plt.title('test-mse-history')
plt.title('test-mse-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix

# Create a figure with two subplots side by side
fig, axs = plt.subplots(1, 5, figsize=(15, 5))

# gene_expr

# Plot the first test KL divergence history on the first subplot
axs[0].plot(test_kl_2.reshape(-1, 10).sum(axis=1), label='lognormal L -test_kl-SNODEP')
axs[0].set_title('Test KL normal')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Plot the first test KL divergence history on the first subplot
axs[1].plot(test_kl_3.reshape(-1, 10).sum(axis=1), label='normal L -test_kl-SNODEP')
axs[1].set_title('Test KL normal')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()

# %%
plt.figure(figsize=(10, 5))

# gene_expr
plt.plot(test_neg_ll_2.reshape(-1, 10).sum(axis=1), label= 'lognormal L -test_neg_ll_normal-SNODEP')
plt.plot(test_neg_ll_3.reshape(-1, 10).sum(axis=1), label= 'normal L -test_neg_ll_normal-SNODEP')

plt.title('test-neg-ll')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Inspect the data
print("Data shape:", training_time.shape)
print("Data type:", type(training_time))
print("Data example:", training_time[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Inspect the data
# ----> 2 print("Data shape:", training_time.shape)
#       3 print("Data type:", type(training_time))
#       4 print("Data example:", training_time[:5])
#
# NameError: name 'training_time' is not defined

# %%
# Inspect the data
print("Data shape:", parameter_count.shape)
print("Data type:", type(parameter_count))
print("Data example:", parameter_count[:5])
# Out:
# Data shape: (1,)
# Data type: <class 'numpy.ndarray'>
# Data example: [135916]

# %% [markdown]
# ## Figures for paper

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_mse_history_2, label= 'Neural ODE Process')
plt.plot(test_mse_history_9, label= 'Neural ODE Process with ordered time')
# plt.plot(test_mse_history_24, label= 'test_mse_history_mean_x_poisson_CDE_backward_LSTM_last_op')
plt.plot(test_mse_history_20, label= 'CSNODEP')
plt.title('test-mse-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix

# # Create a figure with two subplots side by side
# fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# # Plot the first test KL divergence history on the first subplot
# axs[0].plot(test_kl_2.reshape(-1, 10).sum(axis=1), label='Neural ODE Process')
# axs[0].set_title('Test KL normal')
# axs[0].set_xlabel('iteration')
# axs[0].set_ylabel('Loss')
# axs[0].legend()

# axs[1].plot(test_kl_9.reshape(-1, 10).sum(axis=1), label='Neural ODE Process with ordered time')
# axs[1].set_title('Test KL normal')
# axs[1].set_xlabel('iteration')
# axs[1].set_ylabel('Loss')
# axs[1].legend()


# axs[2].plot(test_kl_20.reshape(-1, 10).sum(axis=1), label='CSNODEP')
# axs[2].set_title('Test KL normal')
# axs[2].set_xlabel('iteration')
# axs[2].set_ylabel('Loss')
# axs[2].legend()

# plt.show()


plt.figure(figsize=(10, 5))
plt.plot(test_kl_2.reshape(-1, 10).sum(axis=1), label= 'Neural ODE Process')
plt.plot(test_kl_9.reshape(-1, 10).sum(axis=1), label= 'Neural ODE Process with ordered time')
# plt.plot(test_mse_history_24, label= 'test_mse_history_mean_x_poisson_CDE_backward_LSTM_last_op')
plt.plot(test_kl_20.reshape(-1, 10).sum(axis=1), label= 'CSNODEP')
plt.title('KL-Divergence term')
plt.xlabel('epochs')
plt.ylabel('KL-loss')
plt.legend()
plt.show()
