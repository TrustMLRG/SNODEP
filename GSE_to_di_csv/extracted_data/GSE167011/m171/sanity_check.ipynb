# %%
import pandas as pd

# %%
a= pd.read_csv('d0.csv', index_col=0)

# %%
a.shape
# Out:
# (623, 847)

# %%
a
# Out:
#          muc6865_CTCGATGGCGCA  muc6865_TTTACGGCCATT  muc6865_TCACTATCCGTA  \
# AACS                        0                     0                     1
# AADAT                       0                     0                     0
# AASS                        1                     2                     5
# ABAT                        0                     0                     0
# ACAA1                       0                     0                     0
# ...                       ...                   ...                   ...
# CYP1A2                      0                     0                     0
# TYR                         0                     0                     0
# UGT2B4                      0                     0                     0
# SULT1E1                     0                     0                     0
# LDHAL6B                     0                     0                     0
#
#          muc6865_AGATGACTTAGA  muc6865_ATGAAGGCGTAA  muc6865_GCCATTAAATTA  \
# ...

# %%
a.loc['AACS'].unique()
# Out:
# array([0, 1, 2])
