# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loss_history_2 = np.load('./results/2d/metabolites/ndp/normal_metabolites_1000/loss_history.npy')
test_logp_history_2 = np.load('./results/2d/metabolites/ndp/normal_metabolites_1000/test_logp_history.npy')
test_mse_history_2 = np.load('./results/2d/metabolites/ndp/normal_metabolites_1000/test_mse_history.npy')
test_neg_ll_2 = np.load('./results/2d/metabolites/ndp/normal_metabolites_1000/test_neg_ll.npy')
test_kl_2 = np.load('./results/2d/metabolites/ndp/normal_metabolites_1000/test_kl.npy')
training_time_2 = np.load('./results/2d/metabolites/ndp/normal_metabolites_1000/training_time.npy')
parameter_count_2 = np.load('./results/2d/metabolites/ndp/normal_metabolites_1000/parameter_count.npy')

loss_history_3 = np.load('./results/2d/flux/ndp/normal_flux_1000/loss_history.npy')
test_logp_history_3 = np.load('./results/2d/flux/ndp/normal_flux_1000/test_logp_history.npy')
test_mse_history_3 = np.load('./results/2d/flux/ndp/normal_flux_1000/test_mse_history.npy')
test_neg_ll_3 = np.load('./results/2d/flux/ndp/normal_flux_1000/test_neg_ll.npy')
test_kl_3 = np.load('./results/2d/flux/ndp/normal_flux_1000/test_kl.npy')
training_time_3 = np.load('./results/2d/flux/ndp/normal_flux_1000/training_time.npy')
parameter_count_3 = np.load('./results/2d/flux/ndp/normal_flux_1000/parameter_count.npy')

loss_history_4 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_unseen_tp_test_1000/loss_history.npy')
test_logp_history_4 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_4 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_4 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_4 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_unseen_tp_test_1000/test_kl.npy')
training_time_4 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_unseen_tp_test_1000/training_time.npy')
parameter_count_4 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_unseen_tp_test_1000/parameter_count.npy')

loss_history_5 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_unseen_tp_test_1000/loss_history.npy')
test_logp_history_5 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_5 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_5 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_5 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_unseen_tp_test_1000/test_kl.npy')
training_time_5 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_unseen_tp_test_1000/training_time.npy')
parameter_count_5 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_unseen_tp_test_1000/parameter_count.npy')

"""
normal_flux_random_ordering_ordered_unseen_tp_test_1000
normal_flux_ordered_unseen_tp_test_1000
"""

loss_history_6 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_6 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_6 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_6 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_6 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_6 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_6 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000/parameter_count.npy')


loss_history_7 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_7 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_7 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_7 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_7 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_7 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_7 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000/parameter_count.npy')

loss_history_8 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_8 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_8 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_8 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_8 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_8 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_8 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_test_1000/parameter_count.npy')

loss_history_9 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000/loss_history.npy')
test_logp_history_9 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000/test_logp_history.npy')
test_mse_history_9 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000/test_mse_history.npy')
test_neg_ll_9 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000/test_neg_ll.npy')
test_kl_9 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000/test_kl.npy')
training_time_9 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000/training_time.npy')
parameter_count_9 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000/parameter_count.npy')

"""
1. poisson_but_latent_normal: means that everything is poisson but during test, the sampling is coming from normal
2. unseen_tp is not really unseen_tp, there was a bug here, need to do it again
I've declared a new variable called ordered_time for it

"""



loss_history_10 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_LSTM_last_op_1000/loss_history.npy')
test_logp_history_10 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_10 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_10 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_10 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_LSTM_last_op_1000/test_kl.npy')
training_time_10 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_LSTM_last_op_1000/training_time.npy')
parameter_count_10 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_LSTM_last_op_1000/parameter_count.npy')

loss_history_11 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000/loss_history.npy')
test_logp_history_11 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_11 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_11 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_11 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000/test_kl.npy')
training_time_11 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000/training_time.npy')
parameter_count_11 = np.load('./results/2d/flux_knockout/ndp/normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000/parameter_count.npy')

loss_history_12 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/loss_history.npy')
test_logp_history_12 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_12 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_12 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_12 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/test_kl.npy')
training_time_12 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/training_time.npy')
parameter_count_12 = np.load('./results/2d/flux_knockout_gene_added/ndp/normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/parameter_count.npy')


loss_history_13 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_NODEP_1000/loss_history.npy')
test_logp_history_13 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_NODEP_1000/test_logp_history.npy')
test_mse_history_13 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_NODEP_1000/test_mse_history.npy')
test_neg_ll_13 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_NODEP_1000/test_neg_ll.npy')
test_kl_13 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_NODEP_1000/test_kl.npy')
training_time_13 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_NODEP_1000/training_time.npy')
parameter_count_13 = np.load('./results/2d/flux/ndp/normal_flux_ordered_unseen_tp_NODEP_1000/parameter_count.npy')


################################################# for metabolites

loss_history_14 = np.load('./results/2d/metabolites_knockout/ndp/normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000/loss_history.npy')
test_logp_history_14 = np.load('./results/2d/metabolites_knockout/ndp/normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_14 = np.load('./results/2d/metabolites_knockout/ndp/normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_14 = np.load('./results/2d/metabolites_knockout/ndp/normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_14 = np.load('./results/2d/metabolites_knockout/ndp/normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000/test_kl.npy')
training_time_14 = np.load('./results/2d/metabolites_knockout/ndp/normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000/training_time.npy')
parameter_count_14 = np.load('./results/2d/metabolites_knockout/ndp/normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000/parameter_count.npy')


loss_history_15 = np.load('./results/2d/metabolites_knockout_gene_added/ndp/normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/loss_history.npy')
test_logp_history_15 = np.load('./results/2d/metabolites_knockout_gene_added/ndp/normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/test_logp_history.npy')
test_mse_history_15 = np.load('./results/2d/metabolites_knockout_gene_added/ndp/normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/test_mse_history.npy')
test_neg_ll_15 = np.load('./results/2d/metabolites_knockout_gene_added/ndp/normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/test_neg_ll.npy')
test_kl_15 = np.load('./results/2d/metabolites_knockout_gene_added/ndp/normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/test_kl.npy')
training_time_15 = np.load('./results/2d/metabolites_knockout_gene_added/ndp/normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/training_time.npy')
parameter_count_15 = np.load('./results/2d/metabolites_knockout_gene_added/ndp/normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000/parameter_count.npy')

# %%
plt.figure(figsize=(10, 5))
# plt.plot(loss_history_2, label='loss_history_normal')
# plt.plot(loss_history_3, label='loss_history_normal')
# plt.plot(loss_history_4, label='loss_history_normal_flux_gene_knockout_unseen_tp')
# plt.plot(loss_history_5, label='loss_history_normal_flux_gene_knockout_gene_added_unseen_tp')
# plt.plot(loss_history_6, label='loss_history_normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000')
# plt.plot(loss_history_7, label='loss_history_normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000')
# plt.plot(loss_history_8, label='loss_history_normal_flux_knockout_ordered_unseen_tp_test_1000')
# plt.plot(loss_history_9, label='loss_history_normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000')
# plt.plot(loss_history_10, label='loss_history_normal_flux_ordered_unseen_tp_LSTM_last_op_1000')
# plt.plot(loss_history_11, label='loss_history_normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000')
# plt.plot(loss_history_12, label='loss_history_normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000')

plt.plot(loss_history_14, label='loss_history_normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000')
plt.plot(loss_history_15, label='loss_history_normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000')

plt.title('loss-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(test_logp_history_2, label= 'test_logp_history_normal')
# plt.plot(test_logp_history_3, label= 'test_logp_history_normal')
plt.plot(test_logp_history_4, label= 'test_logp_history_normal_flux_gene_knockout_unseen_tp')
plt.plot(test_logp_history_5, label= 'test_logp_history_normal_flux_gene_knockout_gene_added_unseen_tp')
plt.title('test-logp-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(test_mse_history_2, label= 'test_mse_history_normal')
# plt.plot(test_mse_history_3, label= 'test_mse_history_normal')
# plt.plot(test_mse_history_4, label= 'test_mse_history_normal_flux_gene_knockout_unseen_tp')
# plt.plot(test_mse_history_5, label= 'test_mse_history_normal_flux_gene_knockout_gene_added_unseen_tp')
# plt.plot(test_mse_history_6, label= 'test_mse_history_normal_flux_knockout_random_ordering_ordered_unseen_tp_test_1000')
# plt.plot(test_mse_history_7, label= 'test_mse_history_normal_flux_knockout_gene_added_random_ordering_ordered_unseen_tp_test_1000')
# plt.plot(test_mse_history_8, label= 'test_mse_history_normal_flux_knockout_ordered_unseen_tp_test_1000')
# plt.plot(test_mse_history_9, label= 'test_mse_history_normal_flux_knockout_gene_added_ordered_unseen_tp_test_1000')

# plt.plot(test_mse_history_10, label= 'test_mse_history_normal_flux_ordered_unseen_tp_LSTM_last_op_1000')
# plt.plot(test_mse_history_11, label= 'test_mse_history_normal_flux_knockout_ordered_unseen_tp_LSTM_last_op_1000')
# plt.plot(test_mse_history_12, label= 'test_mse_history_normal_flux_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000')

plt.plot(test_mse_history_14, label= 'test_mse_history_normal_metabolites_knockout_ordered_unseen_tp_LSTM_last_op_1000')
plt.plot(test_mse_history_15, label= 'test_mse_history_normal_metabolites_knockout_gene_added_ordered_unseen_tp_LSTM_last_op_1000')

plt.title('test-mse-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# # Example visualization
# # Let's assume the data is a 1D array or 2D matrix

# Create a figure with two subplots side by side
fig, axs = plt.subplots(1, 4, figsize=(15, 5))

# Plot the first test KL divergence history on the first subplot
# axs[0].plot(test_kl_2.reshape(-1, 10).sum(axis=1), label='test_kl_normal')
axs[0].plot(test_kl_3.reshape(-1, 10).sum(axis=1), label='test_kl_normal')
axs[0].set_title('Test KL normal')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(test_kl_4.reshape(-1, 10).sum(axis=1), label='test_kl_normal_flux_gene_knockout_unseen_tp')
axs[1].set_title('Test KL normal')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()

axs[2].plot(test_kl_5.reshape(-1, 10).sum(axis=1), label='test_kl_normal_flux_gene_knockout_gene_added_unseen_tp')
axs[2].set_title('Test KL normal')
axs[2].set_xlabel('iteration')
axs[2].set_ylabel('Loss')
axs[2].legend()

# Display the plots
plt.show()



# Create a figure with two subplots side by side
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot the first test KL divergence history on the first subplot
# axs[0].plot(test_kl_2.reshape(-1, 10).sum(axis=1), label='test_kl_normal')
axs[0].plot(test_kl_10.reshape(-1, 10).sum(axis=1), label='a')
axs[0].set_title('Test KL normal')
axs[0].set_xlabel('iteration')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(test_kl_11.reshape(-1, 10).sum(axis=1), label='b')
axs[1].set_title('Test KL normal')
axs[1].set_xlabel('iteration')
axs[1].set_ylabel('Loss')
axs[1].legend()

axs[2].plot(test_kl_12.reshape(-1, 10).sum(axis=1), label='c')
axs[2].set_title('Test KL normal')
axs[2].set_xlabel('iteration')
axs[2].set_ylabel('Loss')
axs[2].legend()

# Display the plots
plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(test_neg_ll_2.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal')
plt.plot(test_neg_ll_3.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal')
plt.plot(test_neg_ll_4.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_flux_gene_knockout_unseen_tp')
plt.plot(test_neg_ll_5.reshape(-1, 10).sum(axis=1), label= 'test_neg_ll_normal_flux_gene_knockout_gene_added_unseen_tp')
plt.title('test-neg-ll')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Inspect the data
print("Data shape:", training_time.shape)
print("Data type:", type(training_time))
print("Data example:", training_time[:5])
# Out:
# Data shape: (1,)
# Data type: <class 'numpy.ndarray'>
# Data example: [201.56662297]

# %%
# Inspect the data
print("Data shape:", parameter_count.shape)
print("Data type:", type(parameter_count))
print("Data example:", parameter_count[:5])
# Out:
# Data shape: (1,)
# Data type: <class 'numpy.ndarray'>
# Data example: [135916]

# %% [markdown]
# ## Figures for paper

# %%
plt.figure(figsize=(10, 5))
plt.plot(loss_history_13, label='NODEP')
plt.plot(loss_history_10, label='CSNODEP')

plt.title('ELBO test loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.plot(loss_history_4, label='NODEP')
plt.plot(loss_history_11, label='CSNODEP')

plt.title('ELBO test loss: gene knockout')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(loss_history_2, label='loss_history_normal')

plt.plot(loss_history_4, label='NODEP')
plt.plot(loss_history_11, label='CSNODEP')
# plt.plot(loss_history_5, label='NODEP+gene-added')
plt.plot(loss_history_9, label='NODEP+gene-added')
plt.plot(loss_history_12, label='CSNODEP+gene-added')

plt.title('loss-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_mse_history_13, label= 'NODEP')
plt.plot(test_mse_history_10, label= 'CSNODEP')
plt.title('test-mse-history')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_mse_history_4, label= 'NODEP')
plt.plot(test_mse_history_11, label= 'CSNODEP')
plt.title('test-mse: gene knockout')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(loss_history_2, label='loss_history_normal')

# plt.plot(test_mse_history_4, label='NODEP')
# plt.plot(test_mse_history_11, label='CSNODEP')
plt.plot(test_mse_history_9, label='NODEP+gene-added')
plt.plot(test_mse_history_12, label='CSNODEP+gene-added')

plt.title('test-mse: gene knockout')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
